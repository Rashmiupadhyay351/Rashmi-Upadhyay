# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\Manish'

# %%
df=pd.read_csv('C:\\Users\\Manish\\DS1_C4_S4_Loan_Practice.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df10=df

# %%
# TASK - 1

A= df[(df.Gender=='Male')& (df.Education=='Graduate')&(df.Loan_Status=='Y')]
print(A)
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001002   Male      No          0  Graduate            No
# 2    LP001005   Male     Yes          0  Graduate           Yes
# 4    LP001008   Male      No          0  Graduate            No
# 5    LP001011   Male     Yes          2  Graduate           Yes
# 8    LP001018   Male     Yes          2  Graduate            No
# ..        ...    ...     ...        ...       ...           ...
# 606  LP002961   Male     Yes          1  Graduate            No
# 608  LP002974   Male     Yes          0  Graduate            No
# 610  LP002979   Male     Yes         3+  Graduate            No
# 611  LP002983   Male     Yes          1  Graduate            No
# 612  LP002984   Male     Yes          2  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         146               360
# ...

# %%
# TASK- 2

B=df[(df.Gender=='Female')&(df.Self_Employed=='Yes')&(df.ApplicantIncome >4000)]
print(B)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 113  LP001392  Female      No          1      Graduate           Yes
# 353  LP002142  Female     Yes          0      Graduate           Yes
# 370  LP002194  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 430  LP002377  Female      No          1      Graduate           Yes
# 439  LP002407  Female     Yes          0  Not Graduate           Yes
# 463  LP002489  Female      No          1  Not Graduate           Yes
# 493  LP002582  Female      No          0  Not Graduate           Yes
# 534  LP002731  Female      No          0  Not Graduate           Yes
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 613  LP002990  Female      No          0      Graduate           Yes
#
# ...

# %%
#TASK - 3

C=df[(df.Dependents>"3")&(df.Property_Area=="Rural")&(df.Loan_Status=="Y")]
C['Gender'].value_counts()
# Out:
# Male      12
# Female     1
# Name: Gender, dtype: int64

# %%
#TASK - 4

D=df[(df.LoanAmount>=290)]
print(D)
ac=df.mean(axis=0)
ac
#E=df["ApplicantIncome"] *df["CoapplicantIncome"].sum()/df["ApplicantIncome"].sum()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 9    LP001020    Male     Yes          1  Graduate            No
# 21   LP001046    Male     Yes          1  Graduate            No
# 34   LP001100    Male      No         3+  Graduate            No
# 67   LP001233    Male     Yes          1  Graduate            No
# 126  LP001448    Male     Yes         3+  Graduate            No
# 130  LP001469    Male      No          0  Graduate           Yes
# 135  LP001488    Male     Yes         3+  Graduate            No
# 155  LP001536    Male     Yes         3+  Graduate            No
# 171  LP001585    Male     Yes         3+  Graduate            No
# 177  LP001610    Male     Yes         3+  Graduate            No
# 258  LP001859    Male     Yes          0  Graduate            No
# 260  LP001865    Male     Yes          1  Graduate            No
# 278  LP001907    Male     Yes          0  Graduate            No
# ...

# %%
# TASK - 5
DS= df[(df.Married=='No')&(df.Self_Employed=='Yes')&(df.Loan_Status=='N')]
DS
DS['Gender'].value_counts()
# Out:
# Male      9
# Female    5
# Name: Gender, dtype: int64

# %%
# TASK- 6

Rural= df[(df.Property_Area=='Rural')]
Rural[['Loan_ID','Property_Area','ApplicantIncome']]
# Out:
#       Loan_ID Property_Area  ApplicantIncome
# 1    LP001003         Rural             4583
# 13   LP001029         Rural             1853
# 18   LP001038         Rural             4887
# 23   LP001050         Rural             3365
# 32   LP001097         Rural             4692
# ..        ...           ...              ...
# 603  LP002958         Rural             3676
# 607  LP002964         Rural             3987
# 608  LP002974         Rural             3232
# 609  LP002978         Rural             2900
# 610  LP002979         Rural             4106
#
# [179 rows x 3 columns]

# %%
Urban= df[(df.Property_Area=='Urban')]
Urban[['Loan_ID','Property_Area','ApplicantIncome']]
# Out:
#       Loan_ID Property_Area  ApplicantIncome
# 0    LP001002         Urban             5849
# 2    LP001005         Urban             3000
# 3    LP001006         Urban             2583
# 4    LP001008         Urban             6000
# 5    LP001011         Urban             5417
# ..        ...           ...              ...
# 600  LP002949         Urban              416
# 602  LP002953         Urban             5703
# 605  LP002960         Urban             2400
# 611  LP002983         Urban             8072
# 612  LP002984         Urban             7583
#
# [202 rows x 3 columns]

# %%
Semiurban= df[(df.Property_Area=='Semiurban')]
Semiurban[['Loan_ID','Property_Area','ApplicantIncome']]
# Out:
#       Loan_ID Property_Area  ApplicantIncome
# 7    LP001014     Semiurban             3036
# 9    LP001020     Semiurban            12841
# 22   LP001047     Semiurban             2600
# 24   LP001052     Semiurban             3717
# 25   LP001066     Semiurban             9560
# ..        ...           ...              ...
# 592  LP002933     Semiurban             9357
# 597  LP002943     Semiurban             2987
# 604  LP002959     Semiurban            12000
# 606  LP002961     Semiurban             3400
# 613  LP002990     Semiurban             4583
#
# [233 rows x 3 columns]

# %%
#TASK - 7

avg=df['CoapplicantIncome'].mean()
print("Average income of Coapplicants :",avg)
cus=df[(df.CoapplicantIncome<avg) & (df.Married=='Yes') &(df.Loan_Status=='Y')]
cus
# Out:
# Average income of Coapplicants : 1621.245798027101
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 14   LP001030    Male     Yes          2      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 604  LP002959  Female     Yes          1      Graduate            No
# 607  LP002964    Male     Yes          2  Not Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#TASK - 8

E= df[(df.Education=='Graduate')&(df.ApplicantIncome>10256)&(df.ApplicantIncome<150000)]
gra=E['Education'].value_counts()
print("Number of graduate applicants income between 10256-150000 :",gra)
# Out:
# Number of graduate applicants income between 10256-150000 : Graduate    48
# Name: Education, dtype: int64

# %%
#TASK - 9
F = df[(df.ApplicantIncome<6000)&(df.LoanAmount>200)&(df.Loan_Status=='Y')]
F[['Loan_ID','Gender']]
# Out:
#       Loan_ID  Gender
# 5    LP001011    Male
# 21   LP001046    Male
# 159  LP001552    Male
# 253  LP001843    Male
# 255  LP001846  Female
# 276  LP001903    Male
# 361  LP002170    Male
# 381  LP002229    Male
# 502  LP002615    Male
# 505  LP002622    Male
# 530  LP002717    Male
# 562  LP002820    Male

# %%
#TAASK - 10

g= df[(df.Property_Area=='Semiurban')]
sem=g['Property_Area'].value_counts()
print(sem)

f= df[(df.Property_Area=='Urban')]
ur=f['Property_Area'].value_counts()
print(ur)

df.groupby('Property_Area').size()
# Out:
# Semiurban    233
# Name: Property_Area, dtype: int64
# Urban    202
# Name: Property_Area, dtype: int64
# Property_Area
# Rural        179
# Semiurban    233
# Urban        202
# dtype: int64

# %%
# TASK- 11
#ab=df[(df.Loan_Status=='Y')]

asc=df.sort_values('ApplicantIncome',ascending=False)
asc.head()
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 409  LP002317   Male     Yes         3+  Graduate            No
# 333  LP002101   Male     Yes          0  Graduate            No
# 171  LP001585   Male     Yes         3+  Graduate            No
# 155  LP001536   Male     Yes         3+  Graduate            No
# 185  LP001640   Male     Yes          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 409            81000                0.0         360               360
# 333            63337                0.0         490               180
# 171            51763                0.0         700               300
# 155            39999                0.0         600               180
# 185            39147             4750.0         120               360
#
#      Credit_History Property_Area Loan_Status
# 409               0         Rural           N
# 333               1         Urban           Y
# ...

# %%
# TASK- 12

cust=df[(df.Gender=='Female') & (df.Loan_Status=='Y') & (df.Dependents=='2')] 
cust
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 29   LP001087  Female      No          2      Graduate           Yes
# 146  LP001516  Female     Yes          2      Graduate            No
# 219  LP001734  Female     Yes          2      Graduate            No
# 468  LP002502  Female     Yes          2  Not Graduate           Yes
# 516  LP002670  Female     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 29              3750             2083.0         120               360
# 146            14866                0.0          70               360
# 219             4283             2383.0         127               360
# 468              210             2917.0          98               360
# 516             2031             1632.0         113               480
#
#      Credit_History Property_Area Loan_Status
# 29                1     Semiurban           Y
# ...

# %%
df3=df.copy()

# %%
# TASK- 13
import pandas as pd
new=df[(df.Gender=='Female')&(df.LoanAmount>200)]
new
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 119  LP001422  Female      No          0      Graduate            No
# 148  LP001519  Female      No          0      Graduate            No
# 210  LP001708  Female      No          0      Graduate            No
# 233  LP001776  Female      No          0      Graduate            No
# 255  LP001846  Female      No         3+      Graduate            No
# 493  LP002582  Female      No          0  Not Graduate           Yes
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 600  LP002949  Female      No         3+      Graduate           Yes
# 604  LP002959  Female     Yes          1      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 54             11500                0.0         286               360
# ...

# %%
new['Loan_Amount_Term']= new['Loan_Amount_Term'].replace([360],180 )
new
# Out:
# C:\Users\Manish\AppData\Local\Temp/ipykernel_15064/2660108532.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new['Loan_Amount_Term']= new['Loan_Amount_Term'].replace([360],180 )
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 119  LP001422  Female      No          0      Graduate            No
# 148  LP001519  Female      No          0      Graduate            No
# 210  LP001708  Female      No          0      Graduate            No
# 233  LP001776  Female      No          0      Graduate            No
# 255  LP001846  Female      No         3+      Graduate            No
# ...

# %%
df4=df.copy()

# %%
#TASK 14

df4=df4.rename(columns={'Loan_Amount_Term':'LoanAmountTerm'})
df4
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  LoanAmountTerm  \
# 0               5849                0.0         146             360
# ...

# %%
#TASK 14 (CONTINUE)

df4['LoanAmountTerm']= df4['LoanAmountTerm'].replace([12],60)
df4['LoanAmountTerm']= df4['LoanAmountTerm'].replace([36],60)
df4
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  LoanAmountTerm  \
# 0               5849                0.0         146             360
# ...

# %%
#TASK - 15

df=df[(df.Education=='Graduate') & (df.Self_Employed=='Yes') & (df.ApplicantIncome>10000)]
df[['Loan_ID','ApplicantIncome']]
# Out:
#       Loan_ID  ApplicantIncome
# 54   LP001186            11500
# 128  LP001451            10513
# 130  LP001469            20166
# 185  LP001640            39147
# 199  LP001673            11000
# 254  LP001844            16250
# 370  LP002194            15759
# 432  LP002386            12876
# 438  LP002403            10416
# 475  LP002527            16525
# 478  LP002531            16667
# 525  LP002699            17500
# 557  LP002795            10139
# 561  LP002813            19484
# 594  LP002938            16120

# %%
df5=df

# %%
#TASK- 16
new_df5=df5[(df5.Dependents>'3')&(df5.Credit_History==0)&(df5.Education=='Not Graduate')]
new_df5
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 73   LP001250    Male     Yes         3+  Not Graduate            No
# 338  LP002113  Female      No         3+  Not Graduate            No
# 466  LP002500    Male     Yes         3+  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 73              4755                0.0          95               342
# 338             1830                0.0         146               360
# 466             2947             1664.0          70               180
#
#      Credit_History Property_Area Loan_Status
# 73                0     Semiurban           N
# 338               0         Urban           N
# 466               0         Urban           N

# %%
new_df=new_df5.drop(new_df5.index[2])
new_df5
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 73   LP001250    Male     Yes         3+  Not Graduate            No
# 338  LP002113  Female      No         3+  Not Graduate            No
# 466  LP002500    Male     Yes         3+  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 73              4755                0.0          95               342
# 338             1830                0.0         146               360
# 466             2947             1664.0          70               180
#
#      Credit_History Property_Area Loan_Status
# 73                0     Semiurban           N
# 338               0         Urban           N
# 466               0         Urban           N

# %%
#TASK- 17

#df.groupby('Education').size()
grad=df[df.Education=='Graduate']
grad[['ApplicantIncome']].sum()
# Out:
# ApplicantIncome    2811568
# dtype: int64

# %%
ungrad=df[df.Education=='Not Graduate']
ungrad[['ApplicantIncome']].sum()
# Out:
# ApplicantIncome    506156
# dtype: int64

# %%
graduate_income=df[df['Education']=='Graduate']['ApplicantIncome'].mean()
not_graduate_income=df[df['Education']=='Not Graduate']['ApplicantIncome'].mean()
print("Average income of Graduate customers=",graduate_income)
print("Average income of Not Graduate customers=",not_graduate_income)
# Out:
# Average income of Graduate customers= 5857.433333333333
# Average income of Not Graduate customers= 3777.283582089552
