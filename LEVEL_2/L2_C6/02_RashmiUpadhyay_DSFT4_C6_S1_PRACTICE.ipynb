# %%
import pandas as pd
from string import ascii_letters
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### TASK - 1

# %%
df = pd.read_csv("C:\\Users\\Manish\\Car_sales.csv")
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df.isnull().sum()
# Out:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64

# %%
df1=df.dropna()
df1
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# 5           Audi       A6              18.780               23.555
# ..           ...      ...                 ...                  ...
# 145   Volkswagen     Golf               9.761               11.425
# 146   Volkswagen    Jetta              83.721               13.240
# 147   Volkswagen   Passat              51.102               16.725
# 148   Volkswagen   Cabrio               9.569               16.575
# 149   Volkswagen      GTI               5.596               13.760
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df1.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales_in_thousands     0
# __year_resale_value    0
# Vehicle_type           0
# Price_in_thousands     0
# Engine_size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb_weight            0
# Fuel_capacity          0
# Fuel_efficiency        0
# Latest_Launch          0
# Power_perf_factor      0
# dtype: int64

# %%
df1['Latest_Launch']=pd.to_datetime(df1['Latest_Launch'])

df1['launch_year']=df1['Latest_Launch'].dt.year
df1['launch_month']=df1['Latest_Launch'].dt.month
df1.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
# 5         Audi       A6              18.780               23.555    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
# 5               33.95          2.8       200.0      108.7   76.1   192.0
#
# ...

# %%
#Selecting numeric fields only(dropping unnumerical fields)

df1=df1.drop(['Manufacturer','Model','Vehicle_type','Latest_Launch','__year_resale_value'],axis=1)
df1.head()
# Out:
#    Sales_in_thousands  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0              16.919               21.50          1.8       140.0      101.2
# 1              39.384               28.40          3.2       225.0      108.1
# 3               8.588               42.00          3.5       210.0      114.6
# 4              20.397               23.99          1.8       150.0      102.6
# 5              18.780               33.95          2.8       200.0      108.7
#
#    Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency  \
# 0   67.3   172.4        2.639           13.2             28.0
# 1   70.3   192.9        3.517           17.2             25.0
# 3   71.4   196.6        3.850           18.0             22.0
# 4   68.2   178.0        2.998           16.4             27.0
# 5   76.1   192.0        3.561           18.5             22.0
#
#    Power_perf_factor  launch_year  launch_month
# 0          58.280150         2012             2
# ...

# %% [markdown]
# ### TASK - 2

# %%
#min max scaler

from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaled=scaler.fit_transform(df1)
print(scaled)
# Out:
# [[0.0311018  0.16717781 0.11428571 ... 0.2123145  1.         0.09090909]
#  [0.07266894 0.26122811 0.31428571 ... 0.41302426 0.75       0.45454545]
#  [0.0156869  0.4466026  0.35714286 ... 0.41313952 0.75       0.18181818]
#  ...
#  [0.09435083 0.16308867 0.11428571 ... 0.23306583 1.         0.81818182]
#  [0.01750205 0.14659579 0.14285714 ... 0.15546432 0.75       0.36363636]
#  [0.01015078 0.1126559  0.14285714 ... 0.14963826 0.75       0.27272727]]

# %%
corr=df1.corr()

# %%
mask = np.triu(np.ones_like(corr, dtype=bool))
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(500,100, as_cmap=True)

sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)
plt.show()

# %% [markdown]
# ### TASK - 3

# %%
car  = df1[['Width', 'Length']]
kmeans = KMeans(n_clusters=3,n_init=3).fit(car)
centroids = kmeans.cluster_centers_

print(centroids)

print('Attributes used for cluster model: ', car.columns)

f, ax = plt.subplots(figsize = (15,5))

plt.scatter(car['Width'], car['Length'], c= kmeans.labels_.astype(float), s=50, alpha=0.5)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)
plt.show()
# Out:
# [[ 75.08333333 207.15833333]
#  [ 68.45121951 173.28780488]
#  [ 71.55192308 190.12307692]]
# Attributes used for cluster model:  Index(['Width', 'Length'], dtype='object')

# %%
clustered_df = df1[scale_columns] 
clustered_df['Width'] = df1['Width']
clustered_df['Length'] = df1['Length']
clustered_df['Cluster'] = kmeans.labels_
clustered_df.head()
# Out:
#    Width  Length  Cluster
# 0   67.3   172.4        0
# 1   70.3   192.9        2
# 3   71.4   196.6        2
# 4   68.2   178.0        0
# 5   76.1   192.0        2

# %% [markdown]
# ### TASK - 4

# %%
car  = df1[['Width','Length','Price_in_thousands']]
kmeans = KMeans(n_clusters=3,n_init=3).fit(car)
centroids = kmeans.cluster_centers_

print("Centroids\n",centroids)

print('Attributes used for cluster model: ', car.columns)

f, ax = plt.subplots(figsize = (15,5))

plt.scatter(car['Width'], car['Length'],car['Price_in_thousands'], c= kmeans.labels_.astype(float), alpha=0.5)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red',s=50)
plt.show()
# Out:
# Centroids
#  [[ 73.34313725 199.36470588  26.79884314]
#  [ 68.97857143 177.375       18.57742857]
#  [ 72.59       186.24        63.1353    ]]
# Attributes used for cluster model:  Index(['Width', 'Length', 'Price_in_thousands'], dtype='object')

# %%
clustered_df = df1[scale_columns] 
clustered_df['Width'] = df1['Width']
clustered_df['Length'] = df1['Length']
clustered_df['Price_in_thousands'] = df1['Price_in_thousands']
clustered_df['Cluster'] = kmeans.labels_
clustered_df.head()
# Out:
#    Width  Length  Price_in_thousands  Cluster
# 0   67.3   172.4               21.50        0
# 1   70.3   192.9               28.40        2
# 3   71.4   196.6               42.00        2
# 4   68.2   178.0               23.99        0
# 5   76.1   192.0               33.95        2

# %% [markdown]
# # TASK  5

# %%
cars=[]
for i in range(1,21):
    kmeans=KMeans(n_clusters=i,n_init=10,random_state=1)
    kmeans.fit(df1)
    cars.append(kmeans.inertia_)
cars
# Out:
# [1188707.6326398102,
#  753514.4756652717,
#  482174.06797957595,
#  362262.2460585416,
#  245986.45922460247,
#  204387.27471373978,
#  179187.7932044174,
#  150267.4168201059,
#  129649.2429912283,
#  109936.33283316814,
#  94325.83283537519,
#  85363.40393175707,
#  80661.400185611,
#  74886.89373171992,
#  67309.75973189375,
#  63750.40947134031,
#  60414.76994032604,
#  57474.79124462004,
#  53363.32521936737,
#  51291.07807054431]

# %%
plt.scatter(range(1,21),cars,color='green')
plt.xlabel("Number of clusters")
plt.ylabel("Cars")
plt.show()
