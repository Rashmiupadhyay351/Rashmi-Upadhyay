# %%
import pandas as pd
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\Manish'

# %%
df=pd.read_csv('C:\\Users\\Manish\\car_prices.csv')
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
# TASK- 1
a=df[(df.year==2014)]
a.sort_values('sellingprice').head()
# Out:
#         year      make         model      trim          body transmission  \
# 293223  2014      Ford  E-Series Van     E-250  E-Series Van    automatic
# 185680  2014  Chrysler           200        LX         Sedan    automatic
# 405960  2014      Ford        Escape  Titanium           SUV    automatic
# 174198  2014    Nissan         Versa    1.6 SV         Sedan    automatic
# 174145  2014   Hyundai    Elantra GT      Base     Hatchback    automatic
#
#                       vin state  condition  odometer  color interior  \
# 293223  1ftne2ew6eda13643    tx        4.1   31886.0  white     gray
# 185680  1c3ccbab7en125253    ca        1.0   16973.0  white    black
# 405960  1fmcu9j94eua96505    nj        4.4   20074.0    red    black
# 174198  3n1cn7ap1el855595    il        1.9   15091.0   gray    black
# 174145  kmhd35lh9eu165404    in        2.0       1.0    red    black
#
#                                                    seller    mmr  \
# ...

# %%
# TASK- 2
avg=df[(df.make=='BMW')&(df.year==2010)&(df.condition>4.5)]
av1=avg['sellingprice'].mean()
print("Average selling price of year 2010: ",av1)

avg2=df[(df.make=='BMW')&(df.year==2015)&(df.condition>4.5)]
av2=avg2['sellingprice'].mean()
print("Average selling price of year 2015: ",av2)

prediff = (av2-av1)/av2*100

print("Selling price of BMW cars having a score more than 4.5 in Y2010 is less than by Y2015 is by %f%% "%prediff)
# Out:
# Average selling price of year 2010:  23572.222222222223
# Average selling price of year 2015:  42994.68599033816
# Selling price of BMW cars having a score more than 4.5 in Y2010 is less than by Y2015 is by 45.174103%

# %%
# TASK- 3

avg=df[(df.interior=='black')]
print("Average mmr for Black Interior: ",avg['mmr'].mean())
avg2=df[(df.interior=='gray')]
print("Average mmr for Gray Interior: ",avg2['mmr'].mean())
# Out:
# Average mmr for Black Interior:  15858.52005549485
# Average mmr for Gray Interior:  11189.776545228522

# %%
# TASK-4

car=df[(df.year>=2013)&(df.year<=2015)]
car.groupby(by=['color','year'])['color'].count()
# Out:
# color      year
# beige      2013      875
#            2014      712
#            2015      104
# black      2013    19519
#            2014    14253
#            2015     1974
# blue       2013     7297
#            2014     5878
#            2015      633
# brown      2013     1429
#            2014     1113
#            2015      142
# burgundy   2013     1262
#            2014     1044
#            2015      183
# charcoal   2013       62
#            2014      112
#            2015       13
# gold       2013      817
#            2014      855
#            2015       78
# gray       2013    16312
#            2014    11799
#            2015     1430
# green      2013     1232
#            2014      777
#            2015       87
# lime       2013        7
#            2014        1
# off-white  2013      234
#            2014      122
#            2015       20
# orange     2013      247
#            2014      306
#            2015       32
# pink       2013       21
# ...

# %%
# TASK- 5

dat1=df[(df.saledate=="Fri Dec 19 2014 09:00:00 GMT-0800 (PST)")& (df.body=="SUV")]
ab=dat1['body'].count()
print("Sale of SUV on Fri Dec 19 2014 09:00:00 GMT-0800 (PST):",ab)

dat2=df[(df.saledate=="Thu Jan 15 2015 04:30:00 GMT-0800 (PST)")& (df.body=="SUV")]
ac=dat2['body'].count()
print("Sale of SUV on Thu Jan 15 2015 04:30:00 GMT-0800 (PST):",ac)

diff = (ab-ac)/ab*100
print("Sale with cars body SUV decreased by %f%% "%diff)
# Out:
# Sale of SUV on Fri Dec 19 2014 09:00:00 GMT-0800 (PST): 569
# Sale of SUV on Thu Jan 15 2015 04:30:00 GMT-0800 (PST): 310
# Sale with cars body SUV decreased by 45.518453%

# %%
df2=df.copy()     # Copying data from df to df2 for TASK 6

# %%
# TASK- 6
df2.insert(15, "Discounted_Price",np.nan)

# %%
a=df2[(df2.make=='Ford') | (df2.make=="Chevrolet")]
a['Discounted_Price']=a['sellingprice']*0.9
a
# Out:
# C:\Users\Manish\AppData\Local\Temp/ipykernel_17912/3669322482.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['Discounted_Price']=a['sellingprice']*0.9
#         year       make           model trim         body transmission  \
# 7       2014  Chevrolet           Cruze  1LT        Sedan    automatic
# 9       2014  Chevrolet          Camaro   LT  Convertible    automatic
# 12      2015       Ford          Fusion   SE        Sedan    automatic
# 14      2014  Chevrolet           Cruze  2LT        Sedan    automatic
# 18      2014  Chevrolet          Camaro   LS        Coupe    automatic
# ...      ...        ...             ...  ...          ...          ...
# 558817  2012       Ford            Flex  SEL        Wagon    automatic
# ...

# %%
df3=df.copy()     # coping data from df to df3 for TASK 7

# %%
# TASK- 7 

df3.drop(df3.columns[[6,15]],axis=1, inplace= True)
df3
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission state  condition  odometer   color interior  \
# 0         automatic    ca        5.0   16639.0   white    black
# ...

# %%
#filling missing values
df3.fillna(0)
df3
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission state  condition  odometer   color interior  \
# 0         automatic    ca        5.0   16639.0   white    black
# ...
