# %% [markdown]
# TASK- 1
#
# No of female = 0.46
# no of female part time = 0.25
# part time workers =  0.174
#
# Probability (female) = (0.174 + 0.25) / (0.46/0.25)
#           = 0.424 / 1.84
#           = 0.23
#
# TASK- 2
#
# P(reducing noise) = 0.70
# P(more storage) = 0.67
# P(reducing noise and more storage) = 0.56
#
# So, probability of only for more storage,
#
# p(S) = 0.70 + 0.67 - 0.56
#      = 1.37 - 0.56
#      =0.81
#
# Hence, probability of the workers who believe that increasing more space will increase productivity is = 0.81

# %%
pwd

# %%
import pandas as pd
car_df=pd.read_csv('C:\\Users\\Manish\\DS1_C5_S3_Sampling_Practice_GamesSales_Data.csv')
car_df
# Out:
#                                  Game  Year             Genre  \
# 0                  Grand Theft Auto V  2016            Action
# 1           Call of Duty: Black Ops 3  2017           Shooter
# 2               Red Dead Redemption 2  2020  Action-Adventure
# 3                  Call of Duty: WWII  2019           Shooter
# 4                             FIFA 18  2019            Sports
# ..                                ...   ...               ...
# 704               Hyper Light Drifter  2019      Role-Playing
# 705                         Teslagrad  2016          Platform
# 706  Darius Burst: Chronicle Saviours  2019            Action
# 707   The Escapists: The Walking Dead  2018            Action
# 708                    Super Meat Boy  2018          Platform
#
#                Publisher  North_America_Sales_M$  Europe_Sales_M$  \
# 0         Rockstar Games                    6.06             9.71
# 1             Activision                    6.18             6.05
# ...

# %%
# TASK- 3

# %%
# TASK- 3.1.1
print(car_df.sample(n=20, random_state=1))
# Out:
#                                                   Game  Year  \
# 189                           One Piece: Burning Blood  2018
# 111                                           WWE 2K18  2019
# 551                         Sengoku Basara 4: Sumeragi  2017
# 429  Earth Defense Force 2025.1: The Shadow of New ...  2017
# 666                                 This Is The Police  2019
# 537                                 Starblood Arena VR  2019
# 686                            Battle Garegga Rev.2018  2018
# 139                                              Ni-Oh  2019
# 69                         Dragon Age III: Inquisition  2016
# 335                        Dynasty Warriors 8: Empires  2016
# 47                        Resident Evil VII: Biohazard  2019
# 642                            Super Stardust Ultra VR  2018
# 274                 Dynasty Warriors 8: Xtreme Legends  2016
# 172           Disney Infinity 2.0: Marvel Super Heroes  2016
# ...

# %%
# TASK- 3.1.2
print(car_df.sample(n=20, replace=True, random_state=1))
# Out:
#                                                   Game  Year  \
# 37                                           Far Cry 5  2020
# 235                                  Tales of Zestiria  2017
# 72                             Need for Speed: Payback  2019
# 645  God Eater Off Shot: Tachibana Sakuya-hen Twin ...  2018
# 144                           Injustice: Gods Among Us  2015
# 129                                        LEGO Worlds  2019
# 583                                         Dungeons 3  2019
# 508                    Dead or Alive Xtreme 3: Fortune  2018
# 390                                             MXGP 2  2018
# 281                                       Yooka-Laylee  2019
# 178                           The LEGO Movie Videogame  2016
# 276                        Saint Seiya: Soldiers' Soul  2017
# 254                                             Vampyr  2020
# 357           MXGP 3: The Official Motocross Videogame  2019
# ...

# %%
#TASK- 3.1.3
import numpy as np
indexes=np.arange(0,len(car_df), step=30)
print(car_df.iloc[indexes])
# Out:
#                                            Game  Year             Genre  \
# 0                            Grand Theft Auto V  2016            Action
# 30                         Call of Duty: Ghosts  2015           Shooter
# 60                              Far Cry: Primal  2018  Action-Adventure
# 90               Kingdom Hearts 1.5 + 2.5 Remix  2019      Role-Playing
# 120             Metal Gear Solid: Ground Zeroes  2016  Action-Adventure
# 150             Ni no Kuni II: Revenant Kingdom  2020      Role-Playing
# 180                               Dark Souls II  2017      Role-Playing
# 210                         Lords of the Fallen  2016      Role-Playing
# 240                               Trials Fusion  2016              Misc
# 270                          DmC: Devil May Cry  2017            Action
# 300                              Darksiders III  2020            Action
# 330           Senran Kagura: Peach Beach Splash  2019            Action
# ...

# %%
# TASK- 3.1.4

grouped_d_df=car_df.groupby(['Year'])
genre=car_df.Year.unique()
Strat_Sample_df=pd.DataFrame()

for d in genre:
    d_data= grouped_d_df.get_group(d)
    sample_data=d_data.sample (n=5, replace= True, random_state=1)
    Strat_Sample_df=Strat_Sample_df.append(sample_data, ignore_index= True)
print(Strat_Sample_df)
# Out:
#                                               Game  Year             Genre  \
# 0                                  LEGO The Hobbit  2016  Action-Adventure
# 1                                         NBA 2K15  2016            Sports
# 2                                   Child of Light  2016      Role-Playing
# 3                   Middle-Earth: Shadow of Mordor  2016            Action
# 4                                    Omega Quintet  2016      Role-Playing
# 5                        Pro Evolution Soccer 2016  2017            Sports
# 6                                  Toukiden Kiwami  2017            Action
# 7                        Woodcutter Simulator 2016  2017            Action
# 8                                      Chaos;Child  2017      Visual Novel
# 9                     Brothers: A Tale of Two Sons  2017         Adventure
# 10                       Kingdom Come: Deliverance  2020      Role-Playing
# ...

# %%
# TASK- 3.1.5

grouped_dept_df=car_df.groupby(['Year'])
depts=(car_df.Year)
C_Sample_df=pd.DataFrame()

for dept in depts:
    dept_data=grouped_dept_df.get_group(dept)
    sample_data=dept_data.sample(frac=.2, random_state=1)
    C_Sample_df=C_Sample_df.append(sample_data, ignore_index=True)
    
print(C_Sample_df)
# Out:
#                                       Game  Year     Genre  \
# 0      Lara Croft and the Temple of Osiris  2016    Action
# 1                                Teslagrad  2016  Platform
# 2                            Trials Fusion  2016      Misc
# 3                                  Thief 4  2016    Action
# 4                            The Golf Club  2016    Sports
# ...                                    ...   ...       ...
# 24988                        Dead Rising 2  2018    Action
# 24989          Prototype: Biohazard Bundle  2018    Action
# 24990           Mark McMorris Infinite Air  2018    Sports
# 24991         Hatsune Miku: Project Diva X  2018     Music
# 24992                       UEFA Euro 2018  2018    Sports
#
#                           Publisher  North_America_Sales_M$  Europe_Sales_M$  \
# 0                       Square Enix                    0.00             0.07
# 1                        Rain Games                    0.00             0.01
# ...

# %%
# TASK- 3
plt.hist(car_df['Global_Sales_M$'], bins=15)
plt.xlabel("Global_Sales_M$")
plt.ylabel("Year")
# Out:
# Text(0, 0.5, 'Year')

# %%
sample_data10=car_df.sample(n=10, replace=True,random_state=1)
sample_data20=car_df.sample(n=20, replace=True,random_state=1)
sample_data30=car_df.sample(n=30, replace=True,random_state=1)
sample_data40=car_df.sample(n=40, replace=True,random_state=1)

print(sample_data10)
print(sample_data20)
print(sample_data30)
print(sample_data40)
# Out:
#                                                   Game  Year         Genre  \
# 37                                           Far Cry 5  2020        Action
# 235                                  Tales of Zestiria  2017  Role-Playing
# 72                             Need for Speed: Payback  2019        Racing
# 645  God Eater Off Shot: Tachibana Sakuya-hen Twin ...  2018        Action
# 144                           Injustice: Gods Among Us  2015      Fighting
# 129                                        LEGO Worlds  2019          Misc
# 583                                         Dungeons 3  2019      Strategy
# 508                    Dead or Alive Xtreme 3: Fortune  2018        Sports
# 390                                             MXGP 2  2018        Racing
# 281                                       Yooka-Laylee  2019      Platform
#
#                                   Publisher  North_America_Sales_M$  \
# 37                                  Ubisoft                    1.44
# ...

# %%
# TASK- 3.2.1

print("Mean :")
p_mean1=st.mean(sample_data10['Global_Sales_M$'])
print("Mean sample data10:",p_mean1)
p_mean2=st.mean(sample_data20['Global_Sales_M$'])
print("Mean sample data20:",p_mean2)
p_mean3=st.mean(sample_data30['Global_Sales_M$'])
print("Mean sample data30:",p_mean3)
p_mean4=st.mean(sample_data40['Global_Sales_M$'])
print("Mean sample data40:",p_mean4)

print("Median: ")
p_median1=st.median(sample_data10['Global_Sales_M$'])
print("Median sample data10:",p_median1)
p_median2=st.median(sample_data20['Global_Sales_M$'])
print("Median sample data20:",p_median2)
p_median3=st.median(sample_data30['Global_Sales_M$'])
print("Median sample data30:",p_median3)
p_median4=st.median(sample_data40['Global_Sales_M$'])
print("Median sample data40:",p_median4)

print("Standard deviation:")
p_sd1=st.stdev(sample_data10['Global_Sales_M$'])
print("Standard Deviation sample data10:",p_sd1)
p_sd2=st.stdev(sample_data20['Global_Sales_M$'])
print("Standard Deviation sample data20:",p_sd2)
p_sd3=st.stdev(sample_data30['Global_Sales_M$'])
print("Standard Deviation sample data30:",p_sd3)
p_sd4=st.stdev(sample_data40['Global_Sales_M$'])
print("Standard Deviation sample data40:",p_sd4)
# Out:
# Mean :
# Mean sample data10: 0.925
# Mean sample data20: 0.5755
# Mean sample data30: 0.81
# Mean sample data40: 0.65025
# Median:
# Median sample data10: 0.37
# Median sample data20: 0.22999999999999998
# Median sample data30: 0.2
# Median sample data40: 0.15500000000000003
# Standard deviation:
# Standard Deviation sample data10: 1.263612546102114
# Standard Deviation sample data20: 0.9522741478332691
# Standard Deviation sample data30: 1.72100612112959
# Standard Deviation sample data40: 1.5125941165886048

# %%
#TASK- 3.2.2

#population parameters

import statistics as st
import scipy.stats as sts

p_mean=st.mean(car_df['Global_Sales_M$'])
p_sd=st.stdev(car_df['Global_Sales_M$'])
print("Population Mean= "+str(p_mean))
print("Population SD= "+str(p_sd))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14676/1205861245.py in <module>
#       6 import scipy.stats as sts
#       7
# ----> 8 p_mean=st.mean(car_df['Global_Sales_M$'])
#       9 p_sd=st.stdev(car_df['Global_Sales_M$'])
#      10 print("Population Mean= "+str(p_mean))
#
# NameError: name 'car_df' is not defined

# %%
# TASK- 3.2.3

#Sample Data with size 10
import matplotlib.pyplot as plt

plt.hist(sample_data10['Global_Sales_M$'], bins=10)
plt.xlabel("Global_Sales_M$")
plt.ylabel("Year")
# Out:
# Text(0, 0.5, 'Year')

# %%
#Sample Data with size 20
import matplotlib.pyplot as plt

plt.hist(sample_data20['Global_Sales_M$'], bins=10)
plt.xlabel("Global_Sales_M$")
plt.ylabel("Year")
# Out:
# Text(0, 0.5, 'Year')

# %%
#Sample Data with size 30
import matplotlib.pyplot as plt

plt.hist(sample_data30['Global_Sales_M$'], bins=10)
plt.xlabel("Global_Sales_M$")
plt.ylabel("Year")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14676/929593574.py in <module>
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 plt.hist(sample_data30['Global_Sales_M$'], bins=10)
#       5 plt.xlabel("Global_Sales_M$")
#       6 plt.ylabel("Year")
#
# NameError: name 'sample_data30' is not defined

# %%
#Sample Data with size 40
import matplotlib.pyplot as plt

plt.hist(sample_data40['Global_Sales_M$'], bins=10)
plt.xlabel("Global_Sales_M$")
plt.ylabel("Year")
# Out:
# Text(0, 0.5, 'Year')

# %%
#Distribution shape of Stratified data
ab=car_df.iloc[indexes]
plt.hist(ab['Global_Sales_M$'],bins=10)
plt.xlabel("Global_Sales_M$")
plt.ylabel("Year")
# Out:
# Text(0, 0.5, 'Year')

# %%
# TASK- 3.2.4

# %%
#Central limit theorem
import seaborn as sns
aa=sample_data10.mean()
print("Sample 10: ",sns.distplot(aa))
# Out:
# C:\Users\Manish\AppData\Local\Temp/ipykernel_13620/1339539270.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   aa=sample_data10.mean()
# C:\Users\Manish\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Sample 10:  AxesSubplot(0.125,0.125;0.775x0.755)

# %%
ab=sample_data20.mean()
print("Sample 20: ",sns.distplot(ab))
# Out:
# C:\Users\Manish\AppData\Local\Temp/ipykernel_13620/3536380372.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   ab=sample_data20.mean()
# C:\Users\Manish\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Sample 20:  AxesSubplot(0.125,0.125;0.775x0.755)

# %%
ac=sample_data30.mean()
print("Sample 30: ",sns.distplot(ac))
# Out:
# C:\Users\Manish\AppData\Local\Temp/ipykernel_13620/412975615.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   ac=sample_data30.mean()
# C:\Users\Manish\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Sample 30:  AxesSubplot(0.125,0.125;0.775x0.755)

# %%
ad=sample_data40.mean()
print("Sample 40: ",sns.distplot(ad))
# Out:
# C:\Users\Manish\AppData\Local\Temp/ipykernel_13620/2320948894.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   ad=sample_data40.mean()
# C:\Users\Manish\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Sample 40:  AxesSubplot(0.125,0.125;0.775x0.755)
