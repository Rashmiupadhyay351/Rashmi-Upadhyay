# %%
print("S.NO   Item   Quantity  Cost/Item")

choice=input("""" 
   1.Biscuits  5   20.50
   2.Cereals   10  90.00
   3.Chicken   20  200.00
   4.Oats      20  39.99
   5.Rice      30  79.99
   
   
Please select an item to buy :""")

if choice== "1":
    bis=int(input("Enter quantity of packets: "))
    name=input("Enter your name: ")
    address=input("Enter your address: ")
    dis=int(input("Distance from store: "))
    total= bis*20.50
    delivery=30
    bill=total+delivery
    print("Item cost: ",total)
    print("Total Bill Amount: Item cost + Delivery Charge: ",bill)
    print(name)
    print(address)
    print("Have a nice day!!")
    choice = str(input('Press c to continue or q to quit: '))
   
    
if choice == "2":
    cer=int(input("Enter quantity of packets: "))
    name=input("Enter your name: ")
    address=input("Enter your address: ")
    dis=int(input("Distance from store: "))
    total= cer*90.00
    delivery=30
    bill=total+delivery
    print("Item cost: ",total)
    print("Total Bill Amount: Item cost + Delivery Charge: ",bill)
    print(name)
    print(address)
    print("Have a nice day!!")
    
    
if choice == "3":
    chic=int(input("Enter quantity of Chicken: "))
    name=input("Enter your name: ")
    address=input("Enter your address: ")
    dis=int(input("Distance from store: "))
    total= chic*200.00
    delivery=30
    bill=total+delivery
    print("Item cost: ",total)
    print("Total Bill Amount: Item cost + Delivery Charge: ",bill)
    print(name)
    print(address)
    print("Have a nice day!!")
   
    
if choice == "4":
    oat=int(input("Enter quantity of Oats/packets: "))
    name=input("Enter your name: ")
    address=input("Enter your address: ")
    dis=int(input("Distance from store: "))
    total= oat*39.99
    delivery=30
    bill=total+delivery
    print("Item cost: ",total)
    print("Total Bill Amount: Item cost + Delivery Charge: ",bill)
    print(name)
    print(address)
    print("Have a nice day!!")
    
    
if choice == "5":
    ric=int(input("Enter quantity of rice: "))
    name=input("Enter your name: ")
    address=input("Enter your address: ")
    dis=int(input("Distance from store: "))
    total= ric*79.99
    delivery=30
    bill=total+delivery
    print("Item cost: ",total)
    print("Total Bill Amount: Item cost + Delivery Charge: ",bill)
    print(name)
    print(address)
    print("Have a nice day!!")
    
    
else:
    print("Item not found, Please select available item!!")
# Out:
# S.NO   Item   Quantity  Cost/Item
# "
#    1.Biscuits  5   20.50
#    2.Cereals   10  90.00
#    3.Chicken   20  200.00
#    4.Oats      20  39.99
#    5.Rice      30  79.99
#
#
# Please select an item to buy :6
# Item not found, Please select available item!!
