# %%
pwd
# Out:
# 'C:\\Users\\Manish'

# %%
data=pd.read_excel('C:\\Users\\Manish\\cars_ds.xlsx', sheet_name=0)
print(data)
# Out:
#          F        Make      Model        Variant  Displacement  Cylinders  \
# 0        0        Tata  Nano Genx             Xt         624.0        2.0
# 1        1        Tata  Nano Genx             Xe         624.0        2.0
# 2        2        Tata  Nano Genx        Emax Xm         624.0        2.0
# 3        3        Tata  Nano Genx            Xta         624.0        2.0
# 4        4        Tata  Nano Genx             Xm         624.0        2.0
# ...    ...         ...        ...            ...           ...        ...
# 1271  1271       Honda       City   Vx Mt Diesel        1498.0        4.0
# 1272  1272       Honda       City   Zx Mt Diesel        1498.0        4.0
# 1273  1273       Honda       City  Zx Cvt Petrol        1497.0        4.0
# 1274  1274       Honda       City   V Cvt Petrol        1497.0        4.0
# 1275  1275  Mitsubishi    Montero         3.2 At        3200.0        4.0
#
#       Valves_Per_Cylinder               Drivetrain Cylinder_Configuration  \
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
#TASK- 1

a=data.groupby(by=['City_Mileage_km_litre','Highway_Mileage_km_litre']) 
a.first()
# Out:
#                                                    F           Make  \
# City_Mileage_km_litre Highway_Mileage_km_litre
# 0.00                  14.0                      1242          Skoda
#                       15.7                       114        Hyundai
#                       16.0                      1241          Skoda
#                       18.0                       431           Tata
#                       20.5                       139        Hyundai
# ...                                              ...            ...
# 23.00                 22.0                        62  Maruti Suzuki
# 23.84                 23.0                        55           Tata
#                       24.0                        59           Tata
# 24.00                 24.0                       388        Hyundai
# 24.12                 23.0                       451           Tata
#
#                                                           Model  \
# ...

# %%
#TASK- 2
a=data.groupby(by=['City_Mileage_km_litre','Highway_Mileage_km_litre']) 
a.first()
# Out:
#                                                 isker           Make  \
# City_Mileage_km_litre Highway_Mileage_km_litre
# 0.00                  14.0                       1242          Skoda
#                       15.7                        114        Hyundai
#                       16.0                       1241          Skoda
#                       18.0                        431           Tata
#                       20.5                        139        Hyundai
# ...                                               ...            ...
# 23.00                 22.0                         62  Maruti Suzuki
# 23.84                 23.0                         55           Tata
#                       24.0                         59           Tata
# 24.00                 24.0                        388        Hyundai
# 24.12                 23.0                        451           Tata
#
#                                                           Model  \
# ...

# %%
#TASK -3
grp=data.groupby(by=['Make','Model'])
grp.first()
# Out:
#                                 isker              Variant  Displacement  \
# Make         Model
# Aston Martin Db 11                347                  V12        5198.0
#              Rapide              1057                 Luxe        5935.0
#              Vantage             1056                Coupe        3982.0
# Audi         A3                   248  35 Tdi Premium Plus        1968.0
#              A3 Cabriolet         285              40 Tfsi        1395.0
# ...                               ...                  ...           ...
# Volvo        V40 Cross Country   1027                   D3        1984.0
#              V90 Cross Country   1045       D5 Inscription        1969.0
#              Xc40                 269          D4 Momentum        1969.0
#              Xc60                 801       Inscription D5        1969.0
#              Xc90                 822       D5 Inscription        1969.0
#
#                                 Cylinders  Valves_Per_Cylinder  \
# ...

# %%
# TASK- 3
grp=data.groupby(by=['Body_Type'])
grp2=grp['Model'].count()
grp2
# Out:
# Body_Type
# Convertible             20
# Coupe                   41
# Coupe, Convertible       1
# Crossover               18
# Crossover, SUV           2
# Hatchback              316
# MPV                     39
# MUV                     39
# Pick-up                  3
# SUV                    447
# SUV, Crossover           2
# Sedan                  333
# Sedan, Coupe             2
# Sedan, Crossover         1
# Sports                   3
# Sports, Convertible      2
# Sports, Hatchback        1
# Name: Model, dtype: int64

# %%
Model=['Convertible ','Coupe','Coupe, Convertible','Crossover','Crossover','Hatchback','MPV','MUV','Pick-up','SUV','SUV, Crossover',
       'Sedan','Sedan, Coupe','Sedan, Crossover','Sports','Sports, Convertible','Sports, Hatchback']
Make=[20,41,1,18,2,316,39,39,3,447,2,333,2,1,3,2,1]

# %%
import matplotlib.pyplot as plt
plt.pie(Make, labels = Model, autopct='%.2f %%')
plt.title("Pie chart")
plt.show()

# %%
# TASK- 4 

hyu=data[data['Make']=='Hyundai']['City_Mileage_km_litre'].mean()
man=data[data['Make']=='Mahindra']['City_Mileage_km_litre'].mean()
ren=data[data['Make']=='Renault']['City_Mileage_km_litre'].mean()
sk=data[data['Make']=='Skoda']['City_Mileage_km_litre'].mean()

print("Average mileage of Hyundai is:",hyu)
print("Average mileage of Mahindra is:",man)
print("Average mileage of Renault is:",ren)
print("Average mileage of Skoda is:",sk)
# Out:
# Average mileage of Hyundai is: 8.724846153846153
# Average mileage of Mahindra is: 15.633193277310925
# Average mileage of Renault is: 15.986666666666666
# Average mileage of Skoda is: 9.734883720930231

# %%
# TASK- 5

toyt=data[data['Make']=='Toyota']
toy=toyt.groupby(by=['Make','Model'])['City_Mileage_km_litre'].mean()
print("Average Mileage for Toyota with different models/cars:\n",toy)

mah=data[data['Make']=='Mahindra']
ma=mah.groupby(by=['Make','Model'])['City_Mileage_km_litre'].mean()
print("Average Mileage for Mahindra with different models/cars:\\n",ma)

volk=data[data['Make']=='Volkswagen']
vol=volk.groupby(by=['Make','Model'])['City_Mileage_km_litre'].mean()
print("Average Mileage for Volkswagen with different models/cars:\n",vol)

hyun=data[data['Make']=='Hyundai']
hyu=hyun.groupby(by=['Make','Model'])['City_Mileage_km_litre'].mean()
print("Average Mileage for Hyundai with different models/cars:\n",hyu)
# Out:
# Average Mileage for Toyota with different models/cars:
#  Make    Model
# Toyota  Camry                  0.000000
#         Corolla Altis         12.433333
#         Etios Cross           17.143333
#         Etios Liva            17.700000
#         Fortuner              11.192857
#         Glanza                 0.000000
#         Innova Crysta         11.600000
#         Land Cruiser           5.300000
#         Land Cruiser Prado     7.000000
#         Platinum Etios        16.956000
#         Prius                 15.100000
#         Yaris                  0.000000
# Name: City_Mileage_km_litre, dtype: float64
# Average Mileage for Mahindra with different models/cars:\n Make      Model
# Mahindra  Alturas G4             0.000000
#           Bolero                10.560000
#           Bolero Power Plus     11.900000
#           E Verito             110.000000
#           E2O Plus              80.000000
#           Kuv100 Nxt            18.875000
# ...

# %%
# TASK- 6

av=data.groupby(by=['Make'])['City_Mileage_km_litre'].mean()
av
# Out:
# Make
# Aston Martin         6.700000
# Audi                 6.235484
# Bajaj                0.000000
# Bentley              4.183333
# Bmw                  5.918649
# Bugatti              0.000000
# Datsun              12.568000
# Dc                   8.000000
# Ferrari              2.700000
# Fiat                15.391304
# Force                9.333333
# Ford                 1.239535
# Honda                9.190625
# Hyundai              8.724846
# Icml                 8.600000
# Isuzu                9.900000
# Jaguar               4.460455
# Jeep                 1.996429
# Kia                  0.000000
# Lamborghini          5.076923
# Land Rover           0.000000
# Land Rover Rover     3.391852
# Lexus                7.260000
# Mahindra            15.633193
# Maruti Suzuki       13.005235
# Maruti Suzuki R      0.000000
# Maserati             3.266667
# Mg                   0.000000
# Mini                 2.260000
# Mitsubishi           5.821429
# Nissan               8.454828
# ...

# %%
av.plot.box()
plt.title("Fuel economy")
# Out:
# Text(0.5, 1.0, 'Fuel economy')

# %%
# TASK- 7

dis=data.groupby(by=['Displacement','Fuel_Tank_Capacity_litre'])
dis.first()
# Out:
#                                        isker           Make  \
# Displacement Fuel_Tank_Capacity_litre
# 624.0        15.0                          2           Tata
#              24.0                          0           Tata
# 796.0        35.0                        359  Maruti Suzuki
#              36.0                        882  Maruti Suzuki
# 799.0        28.0                          6         Datsun
# ...                                      ...            ...
# 6592.0       83.0                        351           None
# 6593.0       82.5                        349           None
# 6598.0       80.0                        879           None
# 6749.0       100.0                       354           None
# 6752.0       90.0                        352        Bentley
#
#                                                              Model  \
# Displacement Fuel_Tank_Capacity_litre
# 624.0        15.0                                        Nano Genx
# ...

# %%
#TASK- 8

cap=data.groupby(by=['Fuel_Tank_Capacity_litre'])['City_Mileage_km_litre'].mean()
cap
# Out:
# Fuel_Tank_Capacity_litre
# 15.0      0.000000
# 24.0     23.600000
# 27.0      0.000000
# 28.0     21.531111
# 32.0      6.687619
#            ...
# 93.0      5.900000
# 93.5      9.600000
# 96.0      0.000000
# 100.0     6.854286
# 105.0     2.450000
# Name: City_Mileage_km_litre, Length: 63, dtype: float64

# %%
plt.plot(cap.index, cap.values)
plt.title("Fuel tank capacity trend with mileage coverage ")
# Out:
# Text(0.5, 1.0, 'Fuel tank capacity trend with mileage coverage ')

# %%
# TASK- 9

safe=data[(data.Child_Safety_Locks=='Yes') & (data.Central_Locking=='Yes') & (data.Hill_Assist=='Yes') & (data.High_Speed_Alert_System=='Yes')]
safe
# Out:
#       isker        Make              Model                  Variant  \
# 151     151  Volkswagen               Polo                   Gt Tsi
# 271     271       Volvo               Xc40              T4 R-Design
# 273     273        Audi                 A4     Premium Plus 35 Tfsi
# 274     274        Audi                 A4       Technology 35 Tfsi
# 276     276      Jaguar                 Xe                 S Petrol
# ...     ...         ...                ...                      ...
# 1250   1250       Skoda            Octavia         Onyx 2.0 Tdi Dsg
# 1251   1251         NaN  Mercedes-Benz Glc          200 Progressive
# 1252   1252         NaN  Mercedes-Benz Glc  220D 4Matic Progressive
# 1253   1253     Porsche      Cayenne Coupe                     Base
# 1254   1254     Porsche      Cayenne Coupe                    Turbo
#
#       Displacement  Cylinders  Valves_Per_Cylinder               Drivetrain  \
# ...

# %%
# TASK- 10

data[(data.Drive_Modes=='Normal, Comfort, Eco, Sport, Power Mode')]
# Out:
#      isker  Make Model                    Variant  Displacement  Cylinders  \
# 321    321  Audi    Q8  55 Tfsi Quattro Tiptronic        2995.0        4.0
# 330    330  Audi  A8 L            55 Tfsi Quattro        2995.0        8.0
#
#      Valves_Per_Cylinder             Drivetrain Cylinder_Configuration  \
# 321                  4.0  AWD (All Wheel Drive)                      V
# 330                  4.0  AWD (All Wheel Drive)                      V
#
#          Engine_Location  ... Leather_Wrapped_Steering  Automatic_Headlamps  \
# 321  Front, Longitudinal  ...                      Yes                  NaN
# 330  Front, Longitudinal  ...                      Yes                  NaN
#
#                                            Engine_Type  \
# 321  Roller cam follower, continuous intake and exh...
# 330                                                NaN
#
#      ASR_/_Traction_Control  Cruise_Control  USB_Ports Heads-Up_Display  \
# ...

# %%
# TASK-11

hyun=data[data['Make']=='Hyundai']
hyu=hyun.groupby(by=['Make','Model'])['City_Mileage_km_litre'].mean()
print("Average Mileage for Hyundai with different models/cars:\n",hyu)
# Out:
# Average Mileage for Hyundai with different models/cars:
#  Make     Model
# Hyundai  Aura                0.000000
#          Creta              16.028889
#          Elantra            13.100000
#          Elite I20          15.425000
#          Grand I10          15.750000
#          Grand I10 Nios      2.070000
#          Grand I10 Prime    14.300000
#          I20 Active         16.547500
#          Kona Electric       0.000000
#          Santro              0.000000
#          Tucson             14.840000
#          Venue               0.000000
#          Verna               5.215385
#          Xcent              17.166667
#          Xcent Prime         0.000000
# Name: City_Mileage_km_litre, dtype: float64

# %%
plt.hist(hyun['Model'],bins=25)
# Out:
# (array([ 8.,  6.,  0., 12.,  0., 12.,  0.,  6., 13.,  0.,  4.,  0., 13.,
#          0.,  6.,  0.,  4.,  8.,  0., 10.,  0.,  9.,  0., 18.,  1.]),
#  array([ 0.  ,  0.56,  1.12,  1.68,  2.24,  2.8 ,  3.36,  3.92,  4.48,
#          5.04,  5.6 ,  6.16,  6.72,  7.28,  7.84,  8.4 ,  8.96,  9.52,
#         10.08, 10.64, 11.2 , 11.76, 12.32, 12.88, 13.44, 14.  ]),
#  <BarContainer object of 25 artists>)

# %%
suzuk=data[data['Make']=='Maruti Suzuki']
suzu=suzuk.groupby(by=['Make','Model'])['City_Mileage_km_litre'].mean()
print("Average Mileage for Suzuki with different models/cars:\n",suzu)
# Out:
# Average Mileage for Suzuki with different models/cars:
#  Make           Model
# Maruti Suzuki  Alto              0.000000
#                Alto 800 Tour    18.000000
#                Alto K10         12.500000
#                Baleno           23.243077
#                Baleno Rs        21.400000
#                Celerio          20.909091
#                Celerio Tour     11.500000
#                Celerio X        23.000000
#                Ciaz             15.241429
#                Dzire            22.350000
#                Dzire Tour       10.300000
#                Eeco              7.000000
#                Ertiga            0.000000
#                Gypsy            10.200000
#                Ignis            20.062857
#                Omni             13.000000
#                S-Cross          23.650000
#                S-Presso          0.000000
#                Swift             0.900000
#                Vitara Brezza    20.000000
# ...

# %%
plt.hist(suzuk['Model'], bins=40)
# Out:
# (array([ 5.,  0.,  6.,  0.,  2.,  0.,  8.,  0.,  7.,  0.,  3.,  0., 14.,
#          0.,  8.,  0., 10.,  0., 11.,  0., 14.,  0.,  2.,  0.,  9.,  0.,
#          4.,  0.,  2.,  0., 13.,  0., 10.,  0.,  1.,  0.,  4.,  0.,  2.,
#         14.]),
#  array([ 0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ,
#          5.5,  6. ,  6.5,  7. ,  7.5,  8. ,  8.5,  9. ,  9.5, 10. , 10.5,
#         11. , 11.5, 12. , 12.5, 13. , 13.5, 14. , 14.5, 15. , 15.5, 16. ,
#         16.5, 17. , 17.5, 18. , 18.5, 19. , 19.5, 20. ]),
#  <BarContainer object of 40 artists>)

# %%
tata=data[data['Make']=='Tata']
tat=tata.groupby(by=['Make','Model'])['City_Mileage_km_litre'].mean()
print("Average Mileage for Tata with different models/cars:\n",tat)
# Out:
# Average Mileage for Tata with different models/cars:
#  Make  Model
# Tata  Altroz            0.000000
#       Bolt             20.260000
#       Harrier           0.000000
#       Hexa             14.000000
#       Nano Genx        19.666667
#       Nexon             0.000000
#       Nexon Ev          0.000000
#       Safari Storme    11.582500
#       Tiago            20.860000
#       Tiago Nrg         0.000000
#       Tigor            24.120000
#       Tigor Ev          0.000000
#       Winger            0.000000
#       Zest             17.018182
# Name: City_Mileage_km_litre, dtype: float64

# %%
plt.hist(tata['Model'], bins=30)
# Out:
# (array([ 6.,  0.,  8.,  0.,  8.,  0., 10.,  0.,  0.,  6.,  0., 11.,  0.,
#         24.,  0.,  0.,  3.,  0.,  7.,  0.,  4.,  0.,  0.,  3.,  0.,  6.,
#          0.,  3.,  0.,  1.]),
#  array([ 0.        ,  0.43333333,  0.86666667,  1.3       ,  1.73333333,
#          2.16666667,  2.6       ,  3.03333333,  3.46666667,  3.9       ,
#          4.33333333,  4.76666667,  5.2       ,  5.63333333,  6.06666667,
#          6.5       ,  6.93333333,  7.36666667,  7.8       ,  8.23333333,
#          8.66666667,  9.1       ,  9.53333333,  9.96666667, 10.4       ,
#         10.83333333, 11.26666667, 11.7       , 12.13333333, 12.56666667,
#         13.        ]),
#  <BarContainer object of 30 artists>)

# %%
bmw=data[data['Make']=='Bmw']
bm=bmw.groupby(by=['Make','Model'])['City_Mileage_km_litre'].mean()
print("Average Mileage for BMW with different models/cars:\n",bm)
# Out:
# Average Mileage for BMW with different models/cars:
#  Make  Model
# Bmw   3-Series           0.0000
#       5-Series          12.1700
#       6-Series           1.1125
#       7-Series           6.7500
#       M2 Competition    12.5000
#       M4                 7.3200
#       M5                 0.0000
#       X1                13.9420
#       X3                16.0000
#       X4                 0.0000
#       X5                 0.0000
#       X7                 0.0000
#       Z4 Roadster        0.0000
# Name: City_Mileage_km_litre, dtype: float64

# %%
plt.hist(bmw['Model'], bins=25)
# Out:
# (array([3., 0., 3., 0., 1., 0., 6., 0., 5., 0., 3., 0., 3., 0., 2., 0., 2.,
#         0., 1., 0., 3., 0., 4., 0., 1.]),
#  array([ 0.  ,  0.48,  0.96,  1.44,  1.92,  2.4 ,  2.88,  3.36,  3.84,
#          4.32,  4.8 ,  5.28,  5.76,  6.24,  6.72,  7.2 ,  7.68,  8.16,
#          8.64,  9.12,  9.6 , 10.08, 10.56, 11.04, 11.52, 12.  ]),
#  <BarContainer object of 25 artists>)
